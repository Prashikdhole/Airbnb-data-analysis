# %% [markdown]
# # **Project Name - Hotel Booking Analysis**
#
#
# **Auther** - Prashik Dhole

# %% [markdown]
# ##***Let's Begin !***

# %% [markdown]
# ### **Import All Liabraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### **Loading Dataset**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Airbnb NYC 2019.csv',index_col = 'id')

# %% [markdown]
# ###**Dataset Information**

# %%
df.head(10)
# Out:
#                                                   name  host_id    host_name  \
# id
# 2539                Clean & quiet apt home by the park     2787         John
# 2595                             Skylit Midtown Castle     2845     Jennifer
# 3647               THE VILLAGE OF HARLEM....NEW YORK !     4632    Elisabeth
# 3831                   Cozy Entire Floor of Brownstone     4869  LisaRoxanne
# 5022  Entire Apt: Spacious Studio/Loft by central park     7192        Laura
# 5099         Large Cozy 1 BR Apartment In Midtown East     7322        Chris
# 5121                                   BlissArtsSpace!     7356        Garon
# 5178                  Large Furnished Room Near B'way      8967     Shunichi
# 5203                Cozy Clean Guest Room - Family Apt     7490    MaryEllen
# 5238                Cute & Cozy Lower East Side 1 bdrm     7549          Ben
#
#      neighbourhood_group       neighbourhood  latitude  longitude  \
# id
# ...

# %%
df.tail()
# Out:
#                                                        name   host_id  \
# id
# 36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 36485431            Sunny Studio at Historical Neighborhood  23492952
# 36485609               43rd St. Time Square-cozy single bed  30985759
# 36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#               host_name neighbourhood_group       neighbourhood  latitude  \
# id
# 36484665        Sabrina            Brooklyn  Bedford-Stuyvesant  40.67853
# 36485057        Marisol            Brooklyn            Bushwick  40.70184
# 36485431  Ilgar & Aysel           Manhattan              Harlem  40.81475
# 36485609            Taz           Manhattan      Hell's Kitchen  40.75751
# 36487245     Christophe           Manhattan      Hell's Kitchen  40.76404
#
#           longitude        room_type  price  minimum_nights  \
# id
# ...

# %%
df.shape
# Out:
# (48895, 15)

# %%
df.describe()
# Out:
#             host_id      latitude     longitude         price  minimum_nights  \
# count  4.889500e+04  48895.000000  48895.000000  48895.000000    48895.000000
# mean   6.762001e+07     40.728949    -73.952170    152.720687        7.029962
# std    7.861097e+07      0.054530      0.046157    240.154170       20.510550
# min    2.438000e+03     40.499790    -74.244420      0.000000        1.000000
# 25%    7.822033e+06     40.690100    -73.983070     69.000000        1.000000
# 50%    3.079382e+07     40.723070    -73.955680    106.000000        3.000000
# 75%    1.074344e+08     40.763115    -73.936275    175.000000        5.000000
# max    2.743213e+08     40.913060    -73.712990  10000.000000     1250.000000
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# count       48895.000000       38843.000000                    48895.000000
# mean           23.274466           1.373221                        7.143982
# ...

# %%
df.columns
# Out:
# Index(['name', 'host_id', 'host_name', 'neighbourhood_group', 'neighbourhood',
#        'latitude', 'longitude', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'last_review', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %% [markdown]
# ###**Data Cleaning**

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [name, host_id, host_name, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []

# %%
df.isnull()
# Out:
#            name  host_id  host_name  neighbourhood_group  neighbourhood  \
# id
# 2539      False    False      False                False          False
# 2595      False    False      False                False          False
# 3647      False    False      False                False          False
# 3831      False    False      False                False          False
# 5022      False    False      False                False          False
# ...         ...      ...        ...                  ...            ...
# 36484665  False    False      False                False          False
# 36485057  False    False      False                False          False
# 36485431  False    False      False                False          False
# 36485609  False    False      False                False          False
# 36487245  False    False      False                False          False
#
#           latitude  longitude  room_type  price  minimum_nights  \
# id
# ...

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# last_review                       10052
# reviews_per_month                 10052
# host_name                            21
# name                                 16
# host_id                               0
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
round(df.isnull().sum().sort_values(ascending=False)/len(df)*100,2)
# Out:
# last_review                       20.56
# reviews_per_month                 20.56
# host_name                          0.04
# name                               0.03
# host_id                            0.00
# neighbourhood_group                0.00
# neighbourhood                      0.00
# latitude                           0.00
# longitude                          0.00
# room_type                          0.00
# price                              0.00
# minimum_nights                     0.00
# number_of_reviews                  0.00
# calculated_host_listings_count     0.00
# availability_365                   0.00
# dtype: float64

# %%
df['last_review'].fillna(df['last_review'].value_counts()[0],inplace=True)

# %%
df['last_review'].isnull().sum()
# Out:
# 0

# %%
df['reviews_per_month'].fillna(df['reviews_per_month'].median(),inplace=True)

# %%
df['reviews_per_month'].isnull().sum()
# Out:
# 0

# %%
df['host_name'] = df['host_name'].fillna('others')

# %%
df['host_name'].isnull().sum()
# Out:
# 0

# %%
df['name'] = df['name'].fillna('others')

# %%
df['name'].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
df.head()
# Out:
#                                                   name  host_id    host_name  \
# id
# 2539                Clean & quiet apt home by the park     2787         John
# 2595                             Skylit Midtown Castle     2845     Jennifer
# 3647               THE VILLAGE OF HARLEM....NEW YORK !     4632    Elisabeth
# 3831                   Cozy Entire Floor of Brownstone     4869  LisaRoxanne
# 5022  Entire Apt: Spacious Studio/Loft by central park     7192        Laura
#
#      neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# id
# 2539            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 2595           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 3647           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3831            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 5022           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
# ...

# %%
df.reset_index()
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48895 entries, 2539 to 36487245
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   name                            48895 non-null  object
#  1   host_id                         48895 non-null  int64
#  2   host_name                       48895 non-null  object
#  3   neighbourhood_group             48895 non-null  object
#  4   neighbourhood                   48895 non-null  object
#  5   latitude                        48895 non-null  float64
#  6   longitude                       48895 non-null  float64
#  7   room_type                       48895 non-null  object
#  8   price                           48895 non-null  int64
#  9   minimum_nights                  48895 non-null  int64
#  10  number_of_reviews               48895 non-null  int64
#  11  last_review                     48895 non-null  object
# ...

# %%
df["last_review"] = pd.to_datetime(df["last_review"])

# %%
df['reviews_per_month'] = df['reviews_per_month'].astype('int64')

# %%
df.head()
# Out:
#                                                   name  host_id    host_name  \
# id
# 2539                Clean & quiet apt home by the park     2787         John
# 2595                             Skylit Midtown Castle     2845     Jennifer
# 3647               THE VILLAGE OF HARLEM....NEW YORK !     4632    Elisabeth
# 3831                   Cozy Entire Floor of Brownstone     4869  LisaRoxanne
# 5022  Entire Apt: Spacious Studio/Loft by central park     7192        Laura
#
#      neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# id
# 2539            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 2595           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 3647           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3831            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 5022           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48895 entries, 2539 to 36487245
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   name                            48895 non-null  object
#  1   host_id                         48895 non-null  int64
#  2   host_name                       48895 non-null  object
#  3   neighbourhood_group             48895 non-null  object
#  4   neighbourhood                   48895 non-null  object
#  5   latitude                        48895 non-null  float64
#  6   longitude                       48895 non-null  float64
#  7   room_type                       48895 non-null  object
#  8   price                           48895 non-null  int64
#  9   minimum_nights                  48895 non-null  int64
#  10  number_of_reviews               48895 non-null  int64
#  11  last_review                     48895 non-null  datetime64[ns]
# ...

# %%
df.head()
# Out:
#                                                   name  host_id    host_name  \
# id
# 2539                Clean & quiet apt home by the park     2787         John
# 2595                             Skylit Midtown Castle     2845     Jennifer
# 3647               THE VILLAGE OF HARLEM....NEW YORK !     4632    Elisabeth
# 3831                   Cozy Entire Floor of Brownstone     4869  LisaRoxanne
# 5022  Entire Apt: Spacious Studio/Loft by central park     7192        Laura
#
#      neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# id
# 2539            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 2595           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 3647           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3831            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 5022           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
# ...

# %%
df['year'] = df['last_review'].dt.year

# %%
df['month'] = df['last_review'].dt.month

# %%
df.head()
# Out:
#                                                   name  host_id    host_name  \
# id
# 2539                Clean & quiet apt home by the park     2787         John
# 2595                             Skylit Midtown Castle     2845     Jennifer
# 3647               THE VILLAGE OF HARLEM....NEW YORK !     4632    Elisabeth
# 3831                   Cozy Entire Floor of Brownstone     4869  LisaRoxanne
# 5022  Entire Apt: Spacious Studio/Loft by central park     7192        Laura
#
#      neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# id
# 2539            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 2595           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 3647           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3831            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 5022           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
# ...

# %% [markdown]
# ###**Visualization**

# %% [markdown]
# ## **Univariate Data Analysis**

# %% [markdown]
# **Insight-1**

# %%
df.room_type.value_counts()
# Out:
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# Name: room_type, dtype: int64

# %%
df.room_type.value_counts().plot(kind='bar',figsize=(10,10),title = 'Frequancy of room type')
# Out:
# <Axes: title={'center': 'Frequancy of room type'}>

# %% [markdown]
# **Insight-2**

# %%
sns.scatterplot(data = df['number_of_reviews'])
# Out:
# <Axes: xlabel='id', ylabel='number_of_reviews'>

# %% [markdown]
# **Insight-3**

# %%
sns.scatterplot(data = df['price'])
# Out:
# <Axes: xlabel='id', ylabel='price'>

# %% [markdown]
# **Insight-4**

# %%
sns.scatterplot(data = df['minimum_nights'])
# Out:
# <Axes: xlabel='id', ylabel='minimum_nights'>

# %% [markdown]
# **Insight-5**

# %%
sns.scatterplot(data = df['reviews_per_month'])
# Out:
# <Axes: xlabel='id', ylabel='reviews_per_month'>

# %% [markdown]
# **Insight-6**

# %%
df.calculated_host_listings_count.head()
# Out:
# id
# 2539    6
# 2595    2
# 3647    1
# 3831    1
# 5022    1
# Name: calculated_host_listings_count, dtype: int64

# %%
df.calculated_host_listings_count.value_counts()
# Out:
# 1      32303
# 2       6658
# 3       2853
# 4       1440
# 5        845
# 6        570
# 8        416
# 7        399
# 327      327
# 9        234
# 232      232
# 10       210
# 96       192
# 12       180
# 13       130
# 121      121
# 11       110
# 52       104
# 103      103
# 33        99
# 49        98
# 91        91
# 87        87
# 15        75
# 14        70
# 23        69
# 34        68
# 17        68
# 65        65
# 31        62
# 28        56
# 18        54
# 25        50
# 50        50
# 47        47
# 43        43
# 20        40
# 39        39
# 37        37
# 32        32
# 30        30
# 29        29
# 27        27
# 26        26
# 21        21
# 19        19
# 16        16
# Name: calculated_host_listings_count, dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.countplot(df,x='calculated_host_listings_count')
plt.title('No. of host')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## **Bivariate Data Analysis**

# %% [markdown]
# **Insight-1**

# %%
df['neighbourhood_group'].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
df.groupby(df['neighbourhood_group']).minimum_nights.sum()
# Out:
# neighbourhood_group
# Bronx              4976
# Brooklyn         121761
# Manhattan        185833
# Queens            29358
# Staten Island      1802
# Name: minimum_nights, dtype: int64

# %%
df.groupby(df['neighbourhood_group']).minimum_nights.sum().plot(kind='bar',figsize=(10,10),title = 'total minimumm number of nights among different neighbourhood group')
# Out:
# <Axes: title={'center': 'total minimumm number of nights among different neighbourhood group'}, xlabel='neighbourhood_group'>

# %% [markdown]
# **Insight-2**

# %%
df.room_type.value_counts()
# Out:
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# Name: room_type, dtype: int64

# %%
df.groupby(df['room_type']).minimum_nights.sum()
# Out:
# room_type
# Entire home/apt    216152
# Private room       120067
# Shared room          7511
# Name: minimum_nights, dtype: int64

# %%
df.groupby(df['room_type']).minimum_nights.sum().plot(kind='pie',figsize=(20,10),title='Total no of nights Distribution for room type',autopct='%1.2f%%',startangle=90,shadow=True, labeldistance = 1)
# Out:
# <Axes: title={'center': 'Total no of nights Distribution for room type'}, ylabel='minimum_nights'>

# %% [markdown]
# **Insight-3**

# %%
df.groupby(df['room_type']).availability_365.sum()
# Out:
# room_type
# Entire home/apt    2843783
# Private room       2482739
# Shared room         187921
# Name: availability_365, dtype: int64

# %%
df.groupby(df['room_type']).availability_365.sum().plot(kind='pie',figsize=(20,10),title='Total Availability of room',autopct='%1.2f%%',startangle=90,shadow=True, labeldistance = 1)
# Out:
# <Axes: title={'center': 'Total Availability of room'}, ylabel='availability_365'>

# %% [markdown]
# **Insight-4**

# %%
df.groupby('neighbourhood_group').price.mean()
# Out:
# neighbourhood_group
# Bronx             87.496792
# Brooklyn         124.383207
# Manhattan        196.875814
# Queens            99.517649
# Staten Island    114.812332
# Name: price, dtype: float64

# %%
plt.figure(figsize = (8,5))
fig_x_y = df.groupby('neighbourhood_group').price.mean()
plt.title('Avg room price area wise')
sns.barplot(x =fig_x_y.index,y=fig_x_y.values)
# Out:
# <Axes: title={'center': 'Avg room price area wise'}, xlabel='neighbourhood_group'>

# %% [markdown]
# **Insight-5**

# %%
df.head(10)
# Out:
#                                                   name  host_id    host_name  \
# id
# 2539                Clean & quiet apt home by the park     2787         John
# 2595                             Skylit Midtown Castle     2845     Jennifer
# 3647               THE VILLAGE OF HARLEM....NEW YORK !     4632    Elisabeth
# 3831                   Cozy Entire Floor of Brownstone     4869  LisaRoxanne
# 5022  Entire Apt: Spacious Studio/Loft by central park     7192        Laura
# 5099         Large Cozy 1 BR Apartment In Midtown East     7322        Chris
# 5121                                   BlissArtsSpace!     7356        Garon
# 5178                  Large Furnished Room Near B'way      8967     Shunichi
# 5203                Cozy Clean Guest Room - Family Apt     7490    MaryEllen
# 5238                Cute & Cozy Lower East Side 1 bdrm     7549          Ben
#
#      neighbourhood_group       neighbourhood  latitude  longitude  \
# id
# ...

# %%
df.groupby('room_type').price.mean()
# Out:
# room_type
# Entire home/apt    211.794246
# Private room        89.780973
# Shared room         70.127586
# Name: price, dtype: float64

# %%
plt.figure(figsize = (8,5))
fig_x_y = df.groupby('room_type').price.mean()
plt.title('Avg room price per room type')
sns.barplot(x =fig_x_y.index,y=fig_x_y.values)
# Out:
# <Axes: title={'center': 'Avg room price per room type'}, xlabel='room_type'>

# %% [markdown]
# **Insight-6**

# %%
df.head(10)
# Out:
#                                                   name  host_id    host_name  \
# id
# 2539                Clean & quiet apt home by the park     2787         John
# 2595                             Skylit Midtown Castle     2845     Jennifer
# 3647               THE VILLAGE OF HARLEM....NEW YORK !     4632    Elisabeth
# 3831                   Cozy Entire Floor of Brownstone     4869  LisaRoxanne
# 5022  Entire Apt: Spacious Studio/Loft by central park     7192        Laura
# 5099         Large Cozy 1 BR Apartment In Midtown East     7322        Chris
# 5121                                   BlissArtsSpace!     7356        Garon
# 5178                  Large Furnished Room Near B'way      8967     Shunichi
# 5203                Cozy Clean Guest Room - Family Apt     7490    MaryEllen
# 5238                Cute & Cozy Lower East Side 1 bdrm     7549          Ben
#
#      neighbourhood_group       neighbourhood  latitude  longitude  \
# id
# ...

# %%
df.groupby('neighbourhood_group').host_id.count()
# Out:
# neighbourhood_group
# Bronx             1091
# Brooklyn         20104
# Manhattan        21661
# Queens            5666
# Staten Island      373
# Name: host_id, dtype: int64

# %%
plt.figure(figsize = (8,5))
fig_x_y = df.groupby('neighbourhood_group').host_id.count()
plt.title('No of host per area')
sns.barplot(x =fig_x_y.index,y=fig_x_y.values)
# Out:
# <Axes: title={'center': 'No of host per area'}, xlabel='neighbourhood_group'>

# %% [markdown]
# **Insight-7**

# %%
df.head(10)
# Out:
#                                                   name  host_id    host_name  \
# id
# 2539                Clean & quiet apt home by the park     2787         John
# 2595                             Skylit Midtown Castle     2845     Jennifer
# 3647               THE VILLAGE OF HARLEM....NEW YORK !     4632    Elisabeth
# 3831                   Cozy Entire Floor of Brownstone     4869  LisaRoxanne
# 5022  Entire Apt: Spacious Studio/Loft by central park     7192        Laura
# 5099         Large Cozy 1 BR Apartment In Midtown East     7322        Chris
# 5121                                   BlissArtsSpace!     7356        Garon
# 5178                  Large Furnished Room Near B'way      8967     Shunichi
# 5203                Cozy Clean Guest Room - Family Apt     7490    MaryEllen
# 5238                Cute & Cozy Lower East Side 1 bdrm     7549          Ben
#
#      neighbourhood_group       neighbourhood  latitude  longitude  \
# id
# ...

# %%
df.groupby('room_type').number_of_reviews.sum()
# Out:
# room_type
# Entire home/apt    580403
# Private room       538346
# Shared room         19256
# Name: number_of_reviews, dtype: int64

# %%
plt.figure(figsize = (8,5))
fig_x_y = df.groupby('room_type').number_of_reviews.sum()
plt.title('Total no of reviews for each room type')
sns.barplot(x =fig_x_y.index,y=fig_x_y.values)
# Out:
# <Axes: title={'center': 'Total no of reviews for each room type'}, xlabel='room_type'>

# %% [markdown]
# **Insight-8**

# %%
df.groupby('neighbourhood_group').number_of_reviews.sum()
# Out:
# neighbourhood_group
# Bronx             28371
# Brooklyn         486574
# Manhattan        454569
# Queens           156950
# Staten Island     11541
# Name: number_of_reviews, dtype: int64

# %%
plt.figure(figsize = (8,5))
fig_x_y = df.groupby('neighbourhood_group').number_of_reviews.sum()
plt.title('Total no of reviews for each area')
sns.barplot(x =fig_x_y.index,y=fig_x_y.values)
# Out:
# <Axes: title={'center': 'Total no of reviews for each area'}, xlabel='neighbourhood_group'>

# %% [markdown]
# **Insight-9**

# %%
df.head()
# Out:
#                                                   name  host_id    host_name  \
# id
# 2539                Clean & quiet apt home by the park     2787         John
# 2595                             Skylit Midtown Castle     2845     Jennifer
# 3647               THE VILLAGE OF HARLEM....NEW YORK !     4632    Elisabeth
# 3831                   Cozy Entire Floor of Brownstone     4869  LisaRoxanne
# 5022  Entire Apt: Spacious Studio/Loft by central park     7192        Laura
#
#      neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# id
# 2539            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 2595           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 3647           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3831            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 5022           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
# ...

# %%
plt.figure(figsize = (12,6))
sns.scatterplot(y = 'minimum_nights', x = 'price', data = df[df['price'] < 1000])
plt.show()

# %% [markdown]
# **Insight-10**

# %%
plt.figure(figsize=(12,12))

sns.lineplot(data = df, x = 'number_of_reviews', y = 'price', hue = 'room_type')
plt.show()

# %% [markdown]
# **Insight-11**

# %%
fig = plt.figure(figsize = (10, 5))

# creating the scatter plot
plt.scatter(df['price'], df['number_of_reviews'])

plt.xlabel("Price")
plt.ylabel("Number of Review")
plt.title("Price vs Number of Reviews")
plt.show()

# %% [markdown]
# **Insight-12**

# %%
df.head()
# Out:
#                                                   name  host_id    host_name  \
# id
# 2539                Clean & quiet apt home by the park     2787         John
# 2595                             Skylit Midtown Castle     2845     Jennifer
# 3647               THE VILLAGE OF HARLEM....NEW YORK !     4632    Elisabeth
# 3831                   Cozy Entire Floor of Brownstone     4869  LisaRoxanne
# 5022  Entire Apt: Spacious Studio/Loft by central park     7192        Laura
#
#      neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# id
# 2539            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 2595           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 3647           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3831            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 5022           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
# ...

# %%
grouped = df.groupby('neighbourhood_group')

for group_name, group_data in grouped:
    top_3 = group_data.nlargest(3, 'price')
    print(f'Top 3 neighborhoods in {group_name}:')
    print(top_3[['neighbourhood', 'price']])
# Out:
# Top 3 neighborhoods in Bronx:
#          neighbourhood  price
# id
# 19698169     Riverdale   2500
# 36177241   City Island   1000
# 20330081     Riverdale    800
# Top 3 neighborhoods in Brooklyn:
#           neighbourhood  price
# id
# 13894339     Greenpoint  10000
# 2953058    Clinton Hill   8000
# 34895693  East Flatbush   7500
# Top 3 neighborhoods in Manhattan:
#             neighbourhood  price
# id
# 22436899  Upper West Side  10000
# 4737930       East Harlem   9999
# 9528920   Lower East Side   9999
# Top 3 neighborhoods in Queens:
#          neighbourhood  price
# id
# 7003697        Astoria  10000
# 33133321       Bayside   2600
# 13963005  Forest Hills   2350
# Top 3 neighborhoods in Staten Island:
#           neighbourhood  price
# id
# 18051877  Randall Manor   5000
# 34835762   Prince's Bay   1250
# 4623622      St. George   1000

# %%
fig = plt.figure(figsize = (10, 5))
for group_name, group_data in grouped:
    top_3 = group_data.nlargest(3, 'price')

    plt.figure()
    plt.pie(top_3['price'], labels=top_3['neighbourhood'], autopct='%1.1f%%' )
    plt.title(f'Top 3 neighborhoods in {group_name}')
    plt.show()
